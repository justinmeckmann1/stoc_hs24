# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import metropolis_commands as mc

plt.rcParams['figure.figsize'] = [10, 5]

# %%
mc.metro_beta_walk_hist(n=10000, a=5, b=2, init=0.8, step_sd=.2)
