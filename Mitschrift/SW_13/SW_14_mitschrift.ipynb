# %%
# SW 14
from pandas import DataFrame
import scipy.stats as st
import numpy as np
import matplotlib.pyplot as plt

# %%
rf = DataFrame({
"HC": np.repeat(["5%", "10%", "15%", "20%"], [6, 6, 6, 6]),
"Strength":[7, 8, 15, 11, 9, 10, 12, 17, 13, 18, 19, 15, 14, 18, 19, 17, 16, 18, 19, 25, 22, 23, 18, 20]
})

# %%
fig, ax = plt.subplots()
rf.boxplot(column="Strength", by="HC", ax=ax, grid=False)
# Out:
# <Axes: title={'center': 'Strength'}, xlabel='HC'>

# %%
import seaborn as sns
sns.boxplot(x="HC", y="Strength", data=rf)
# Out:
# <Axes: xlabel='HC', ylabel='Strength'>
